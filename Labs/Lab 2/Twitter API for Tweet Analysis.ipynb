# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Note: As of July 2018, you have to create a developer account in addition to creating twitter account. Developer account url: https://developer.twitter.com/en/apply/user
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentialss.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))
    # rb = Read the file in Binary mode

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x00000220F2654080>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID (WOEID).
#
# The Yahoo! Where On Earth ID for the entire world is 1.<br>
# See https://developer.twitter.com/en/docs/trends/trends-for-location/api-reference/get-trends-place and http://woeid.rosselliot.co.nz/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=23424922 #Pakistan #san-diego 2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[0]
# Out:
# {'trends': [{'name': '#عطنا_حكمه_حلوه_من_عندك',
#    'url': 'http://twitter.com/search?q=%23%D8%B9%D8%B7%D9%86%D8%A7_%D8%AD%D9%83%D9%85%D9%87_%D8%AD%D9%84%D9%88%D9%87_%D9%85%D9%86_%D8%B9%D9%86%D8%AF%D9%83',
#    'promoted_content': None,
#    'query': '%23%D8%B9%D8%B7%D9%86%D8%A7_%D8%AD%D9%83%D9%85%D9%87_%D8%AD%D9%84%D9%88%D9%87_%D9%85%D9%86_%D8%B9%D9%86%D8%AF%D9%83',
#    'tweet_volume': 18464},
#   {'name': '#اكله_مستحيل_تاكلها',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%83%D9%84%D9%87_%D9%85%D8%B3%D8%AA%D8%AD%D9%8A%D9%84_%D8%AA%D8%A7%D9%83%D9%84%D9%87%D8%A7',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%83%D9%84%D9%87_%D9%85%D8%B3%D8%AA%D8%AD%D9%8A%D9%84_%D8%AA%D8%A7%D9%83%D9%84%D9%87%D8%A7',
#    'tweet_volume': None},
#   {'name': '#FelizJueves',
#    'url': 'http://twitter.com/search?q=%23FelizJueves',
#    'promoted_content': None,
#    'query': '%23FelizJueves',
#    'tweet_volume': 19235},
#   {'name': '#RoaldDahlDay2018',
#    'url': 'http://twitter.com/search?q=%23RoaldDahlDay2018',
#    'promoted_content': None,
#    'query': '%23RoaldDahlDay2018',
#    'tweet_volume': 10251},
#   {'name': '#死ぬからの予測変換で生き返ってみせる',
#    'url': 'http://twitter.com/search?q=%23%E6%AD%BB%E3%81%AC%E3%81%8B%E3%82%89%E3%81%AE%E4%BA%88%E6%B8%AC%E5%A4%89%E6%8F%9B%E3%81%A7%E7%94%9F%E3%81%8D%E8%BF%94%E3%81%A3%E3%81%A6%E3%81%BF%E3%81%9B%E3%82%8B',
#    'promoted_content': None,
#    'query': '%23%E6%AD%BB%E3%81%AC%E3%81%8B%E3%82%89%E3%81%AE%E4%BA%88%E6%B8%AC%E5%A4%89%E6%8F%9B%E3%81%A7%E7%94%9F%E3%81%8D%E8%BF%94%E3%81%A3%E3%81%A6%E3%81%BF%E3%81%9B%E3%82%8B',
#    'tweet_volume': 26286},
#   {'name': 'Merkez Bankası',
#    'url': 'http://twitter.com/search?q=%22Merkez+Bankas%C4%B1%22',
#    'promoted_content': None,
#    'query': '%22Merkez+Bankas%C4%B1%22',
#    'tweet_volume': 10637},
#   {'name': 'Salisbury Cathedral',
#    'url': 'http://twitter.com/search?q=%22Salisbury+Cathedral%22',
#    'promoted_content': None,
#    'query': '%22Salisbury+Cathedral%22',
#    'tweet_volume': None},
#   {'name': 'Golden Sun',
#    'url': 'http://twitter.com/search?q=%22Golden+Sun%22',
#    'promoted_content': None,
#    'query': '%22Golden+Sun%22',
#    'tweet_volume': None},
#   {'name': '聚楽第',
#    'url': 'http://twitter.com/search?q=%E8%81%9A%E6%A5%BD%E7%AC%AC',
#    'promoted_content': None,
#    'query': '%E8%81%9A%E6%A5%BD%E7%AC%AC',
#    'tweet_volume': 46696},
#   {'name': 'Солсбери',
#    'url': 'http://twitter.com/search?q=%D0%A1%D0%BE%D0%BB%D1%81%D0%B1%D0%B5%D1%80%D0%B8',
#    'promoted_content': None,
#    'query': '%D0%A1%D0%BE%D0%BB%D1%81%D0%B1%D0%B5%D1%80%D0%B8',
#    'tweet_volume': None},
#   {'name': 'Ruth Beitia',
#    'url': 'http://twitter.com/search?q=%22Ruth+Beitia%22',
#    'promoted_content': None,
#    'query': '%22Ruth+Beitia%22',
#    'tweet_volume': None},
#   {'name': 'Franco del Valle',
#    'url': 'http://twitter.com/search?q=%22Franco+del+Valle%22',
#    'promoted_content': None,
#    'query': '%22Franco+del+Valle%22',
#    'tweet_volume': None},
#   {'name': 'John Lewis',
#    'url': 'http://twitter.com/search?q=%22John+Lewis%22',
#    'promoted_content': None,
#    'query': '%22John+Lewis%22',
#    'tweet_volume': None},
#   {'name': 'アニポケ',
#    'url': 'http://twitter.com/search?q=%E3%82%A2%E3%83%8B%E3%83%9D%E3%82%B1',
#    'promoted_content': None,
#    'query': '%E3%82%A2%E3%83%8B%E3%83%9D%E3%82%B1',
#    'tweet_volume': None},
#   {'name': 'VRカレシ',
#    'url': 'http://twitter.com/search?q=VR%E3%82%AB%E3%83%AC%E3%82%B7',
#    'promoted_content': None,
#    'query': 'VR%E3%82%AB%E3%83%AC%E3%82%B7',
#    'tweet_volume': 13623},
#   {'name': 'GT-R',
#    'url': 'http://twitter.com/search?q=GT-R',
#    'promoted_content': None,
#    'query': 'GT-R',
#    'tweet_volume': None},
#   {'name': '#ThursdayThoughts',
#    'url': 'http://twitter.com/search?q=%23ThursdayThoughts',
#    'promoted_content': None,
#    'query': '%23ThursdayThoughts',
#    'tweet_volume': 31407},
#   {'name': '#DiaInternacionalDelChocolate',
#    'url': 'http://twitter.com/search?q=%23DiaInternacionalDelChocolate',
#    'promoted_content': None,
#    'query': '%23DiaInternacionalDelChocolate',
#    'tweet_volume': None},
#   {'name': '#وجهك_طويل_او_قصير_او_دايري',
#    'url': 'http://twitter.com/search?q=%23%D9%88%D8%AC%D9%87%D9%83_%D8%B7%D9%88%D9%8A%D9%84_%D8%A7%D9%88_%D9%82%D8%B5%D9%8A%D8%B1_%D8%A7%D9%88_%D8%AF%D8%A7%D9%8A%D8%B1%D9%8A',
#    'promoted_content': None,
#    'query': '%23%D9%88%D8%AC%D9%87%D9%83_%D8%B7%D9%88%D9%8A%D9%84_%D8%A7%D9%88_%D9%82%D8%B5%D9%8A%D8%B1_%D8%A7%D9%88_%D8%AF%D8%A7%D9%8A%D8%B1%D9%8A',
#    'tweet_volume': None},
#   {'name': '#GaneshChaturthi',
#    'url': 'http://twitter.com/search?q=%23GaneshChaturthi',
#    'promoted_content': None,
#    'query': '%23GaneshChaturthi',
#    'tweet_volume': 159665},
#   {'name': '#레진대표_미성년자착취',
#    'url': 'http://twitter.com/search?q=%23%EB%A0%88%EC%A7%84%EB%8C%80%ED%91%9C_%EB%AF%B8%EC%84%B1%EB%85%84%EC%9E%90%EC%B0%A9%EC%B7%A8',
#    'promoted_content': None,
#    'query': '%23%EB%A0%88%EC%A7%84%EB%8C%80%ED%91%9C_%EB%AF%B8%EC%84%B1%EB%85%84%EC%9E%90%EC%B0%A9%EC%B7%A8',
#    'tweet_volume': 22970},
#   {'name': '#PlanPauvreté',
#    'url': 'http://twitter.com/search?q=%23PlanPauvret%C3%A9',
#    'promoted_content': None,
#    'query': '%23PlanPauvret%C3%A9',
#    'tweet_volume': 14138},
#   {'name': '#اليوم_العالمي_للقانون',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A_%D9%84%D9%84%D9%82%D8%A7%D9%86%D9%88%D9%86',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A_%D9%84%D9%84%D9%82%D8%A7%D9%86%D9%88%D9%86',
#    'tweet_volume': None},
#   {'name': '#تصريح_مدير_جامعه_شقراء',
#    'url': 'http://twitter.com/search?q=%23%D8%AA%D8%B5%D8%B1%D9%8A%D8%AD_%D9%85%D8%AF%D9%8A%D8%B1_%D8%AC%D8%A7%D9%85%D8%B9%D9%87_%D8%B4%D9%82%D8%B1%D8%A7%D8%A1',
#    'promoted_content': None,
#    'query': '%23%D8%AA%D8%B5%D8%B1%D9%8A%D8%AD_%D9%85%D8%AF%D9%8A%D8%B1_%D8%AC%D8%A7%D9%85%D8%B9%D9%87_%D8%B4%D9%82%D8%B1%D8%A7%D8%A1',
#    'tweet_volume': 129674},
#   {'name': '#الخميس',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AE%D9%85%D9%8A%D8%B3',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%84%D8%AE%D9%85%D9%8A%D8%B3',
#    'tweet_volume': 48954},
#   {'name': '#جواز_الامارات_تاسع_اقوي_جواز',
#    'url': 'http://twitter.com/search?q=%23%D8%AC%D9%88%D8%A7%D8%B2_%D8%A7%D9%84%D8%A7%D9%85%D8%A7%D8%B1%D8%A7%D8%AA_%D8%AA%D8%A7%D8%B3%D8%B9_%D8%A7%D9%82%D9%88%D9%8A_%D8%AC%D9%88%D8%A7%D8%B2',
#    'promoted_content': None,
#    'query': '%23%D8%AC%D9%88%D8%A7%D8%B2_%D8%A7%D9%84%D8%A7%D9%85%D8%A7%D8%B1%D8%A7%D8%AA_%D8%AA%D8%A7%D8%B3%D8%B9_%D8%A7%D9%82%D9%88%D9%8A_%D8%AC%D9%88%D8%A7%D8%B2',
#    'tweet_volume': None},
#   {'name': '#MetinOktay',
#    'url': 'http://twitter.com/search?q=%23MetinOktay',
#    'promoted_content': None,
#    'query': '%23MetinOktay',
#    'tweet_volume': 19857},
#   {'name': '#quizjam_ko',
#    'url': 'http://twitter.com/search?q=%23quizjam_ko',
#    'promoted_content': None,
#    'query': '%23quizjam_ko',
#    'tweet_volume': None},
#   {'name': '#SakaryaMeydanMuharebesi',
#    'url': 'http://twitter.com/search?q=%23SakaryaMeydanMuharebesi',
#    'promoted_content': None,
#    'query': '%23SakaryaMeydanMuharebesi',
#    'tweet_volume': None},
#   {'name': '#公式ナカノヒトの悩み',
#    'url': 'http://twitter.com/search?q=%23%E5%85%AC%E5%BC%8F%E3%83%8A%E3%82%AB%E3%83%8E%E3%83%92%E3%83%88%E3%81%AE%E6%82%A9%E3%81%BF',
#    'promoted_content': None,
#    'query': '%23%E5%85%AC%E5%BC%8F%E3%83%8A%E3%82%AB%E3%83%8E%E3%83%92%E3%83%88%E3%81%AE%E6%82%A9%E3%81%BF',
#    'tweet_volume': 14881},
#   {'name': '#رساله_توجهها_للحاسد',
#    'url': 'http://twitter.com/search?q=%23%D8%B1%D8%B3%D8%A7%D9%84%D9%87_%D8%AA%D9%88%D8%AC%D9%87%D9%87%D8%A7_%D9%84%D9%84%D8%AD%D8%A7%D8%B3%D8%AF',
#    'promoted_content': None,
#    'query': '%23%D8%B1%D8%B3%D8%A7%D9%84%D9%87_%D8%AA%D9%88%D8%AC%D9%87%D9%87%D8%A7_%D9%84%D9%84%D8%AD%D8%A7%D8%B3%D8%AF',
#    'tweet_volume': None},
#   {'name': '#Perşembe',
#    'url': 'http://twitter.com/search?q=%23Per%C5%9Fembe',
#    'promoted_content': None,
#    'query': '%23Per%C5%9Fembe',
#    'tweet_volume': 13266},
#   {'name': '#ArunJaitleyStepDown',
#    'url': 'http://twitter.com/search?q=%23ArunJaitleyStepDown',
#    'promoted_content': None,
#    'query': '%23ArunJaitleyStepDown',
#    'tweet_volume': 23054},
#   {'name': '#HambacherForst',
#    'url': 'http://twitter.com/search?q=%23HambacherForst',
#    'promoted_content': None,
#    'query': '%23HambacherForst',
#    'tweet_volume': 16362},
#   {'name': '#13settembre',
#    'url': 'http://twitter.com/search?q=%2313settembre',
#    'promoted_content': None,
#    'query': '%2313settembre',
#    'tweet_volume': None},
#   {'name': '#JeudiPhoto',
#    'url': 'http://twitter.com/search?q=%23JeudiPhoto',
#    'promoted_content': None,
#    'query': '%23JeudiPhoto',
#    'tweet_volume': None},
#   {'name': '#PSGxJordan',
#    'url': 'http://twitter.com/search?q=%23PSGxJordan',
#    'promoted_content': None,
#    'query': '%23PSGxJordan',
#    'tweet_volume': None},
#   {'name': '#PersibDay',
#    'url': 'http://twitter.com/search?q=%23PersibDay',
#    'promoted_content': None,
#    'query': '%23PersibDay',
#    'tweet_volume': None},
#   {'name': '#WorldSepsisDay',
#    'url': 'http://twitter.com/search?q=%23WorldSepsisDay',
#    'promoted_content': None,
#    'query': '%23WorldSepsisDay',
#    'tweet_volume': None},
#   {'name': '#anipoke',
#    'url': 'http://twitter.com/search?q=%23anipoke',
#    'promoted_content': None,
#    'query': '%23anipoke',
#    'tweet_volume': 16771},
#   {'name': '#QuintaDetremuraSDV',
#    'url': 'http://twitter.com/search?q=%23QuintaDetremuraSDV',
#    'promoted_content': None,
#    'query': '%23QuintaDetremuraSDV',
#    'tweet_volume': 11078},
#   {'name': '#DER18Madrid',
#    'url': 'http://twitter.com/search?q=%23DER18Madrid',
#    'promoted_content': None,
#    'query': '%23DER18Madrid',
#    'tweet_volume': None},
#   {'name': '#마음당_절대_안치이는_요소',
#    'url': 'http://twitter.com/search?q=%23%EB%A7%88%EC%9D%8C%EB%8B%B9_%EC%A0%88%EB%8C%80_%EC%95%88%EC%B9%98%EC%9D%B4%EB%8A%94_%EC%9A%94%EC%86%8C',
#    'promoted_content': None,
#    'query': '%23%EB%A7%88%EC%9D%8C%EB%8B%B9_%EC%A0%88%EB%8C%80_%EC%95%88%EC%B9%98%EC%9D%B4%EB%8A%94_%EC%9A%94%EC%86%8C',
#    'tweet_volume': None},
#   {'name': '#ぐるナイ',
#    'url': 'http://twitter.com/search?q=%23%E3%81%90%E3%82%8B%E3%83%8A%E3%82%A4',
#    'promoted_content': None,
#    'query': '%23%E3%81%90%E3%82%8B%E3%83%8A%E3%82%A4',
#    'tweet_volume': None},
#   {'name': '#تكريم_اليسا',
#    'url': 'http://twitter.com/search?q=%23%D8%AA%D9%83%D8%B1%D9%8A%D9%85_%D8%A7%D9%84%D9%8A%D8%B3%D8%A7',
#    'promoted_content': None,
#    'query': '%23%D8%AA%D9%83%D8%B1%D9%8A%D9%85_%D8%A7%D9%84%D9%8A%D8%B3%D8%A7',
#    'tweet_volume': None},
#   {'name': '#서랍안에_들어있는것',
#    'url': 'http://twitter.com/search?q=%23%EC%84%9C%EB%9E%8D%EC%95%88%EC%97%90_%EB%93%A4%EC%96%B4%EC%9E%88%EB%8A%94%EA%B2%83',
#    'promoted_content': None,
#    'query': '%23%EC%84%9C%EB%9E%8D%EC%95%88%EC%97%90_%EB%93%A4%EC%96%B4%EC%9E%88%EB%8A%94%EA%B2%83',
#    'tweet_volume': None},
#   {'name': '#NSCKE2018',
#    'url': 'http://twitter.com/search?q=%23NSCKE2018',
#    'promoted_content': None,
#    'query': '%23NSCKE2018',
#    'tweet_volume': None},
#   {'name': '#IPeekedOutMyWindow',
#    'url': 'http://twitter.com/search?q=%23IPeekedOutMyWindow',
#    'promoted_content': None,
#    'query': '%23IPeekedOutMyWindow',
#    'tweet_volume': None},
#   {'name': '#عتق_رقبه_حمدان_النفيعي',
#    'url': 'http://twitter.com/search?q=%23%D8%B9%D8%AA%D9%82_%D8%B1%D9%82%D8%A8%D9%87_%D8%AD%D9%85%D8%AF%D8%A7%D9%86_%D8%A7%D9%84%D9%86%D9%81%D9%8A%D8%B9%D9%8A',
#    'promoted_content': None,
#    'query': '%23%D8%B9%D8%AA%D9%82_%D8%B1%D9%82%D8%A8%D9%87_%D8%AD%D9%85%D8%AF%D8%A7%D9%86_%D8%A7%D9%84%D9%86%D9%81%D9%8A%D8%B9%D9%8A',
#    'tweet_volume': None},
#   {'name': '#FMQs',
#    'url': 'http://twitter.com/search?q=%23FMQs',
#    'promoted_content': None,
#    'query': '%23FMQs',
#    'tweet_volume': None}],
#  'as_of': '2018-09-13T11:24:21Z',
#  'created_at': '2018-09-13T11:19:25Z',
#  'locations': [{'name': 'Worldwide', 'woeid': 1}]}

# %%
trends=local_trends
#print(type(trends))
#print(list(trends[0].keys())) #keys/attributes from trend 
#print(trends[0]['trends'])
trends = trends[0]['trends']
print(trends[20])
# Out:
# {'name': '#Putin', 'url': 'http://twitter.com/search?q=%23Putin', 'promoted_content': None, 'query': '%23Putin', 'tweet_volume': None}

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#ThursdayThoughts",
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "promoted_content": null,
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 31407
#    },
#    {
#     "name": "#PrimaryDay",
#     "url": "http://twitter.com/search?q=%23PrimaryDay",
#     "promoted_content": null,
#     "query": "%23PrimaryDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "Category 2",
#     "url": "http://twitter.com/search?q=%22Category+2%22",
#     "promoted_content": null,
#     "query": "%22Category+2%22",
#     "tweet_volume": 11219
#    },
#    {
#     "name": "#IPeekedOutMyWindow",
#     "url": "http://twitter.com/search?q=%23IPeekedOutMyWindow",
#     "promoted_content": null,
#     "query": "%23IPeekedOutMyWindow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThingsDuctTapeCantFix",
#     "url": "http://twitter.com/search?q=%23ThingsDuctTapeCantFix",
#     "promoted_content": null,
#     "query": "%23ThingsDuctTapeCantFix",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vatican OKs",
#     "url": "http://twitter.com/search?q=%22Vatican+OKs%22",
#     "promoted_content": null,
#     "query": "%22Vatican+OKs%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bakersfield",
#     "url": "http://twitter.com/search?q=Bakersfield",
#     "promoted_content": null,
#     "query": "Bakersfield",
#     "tweet_volume": 16025
#    },
#    {
#     "name": "#FridayEve",
#     "url": "http://twitter.com/search?q=%23FridayEve",
#     "promoted_content": null,
#     "query": "%23FridayEve",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trump's FEMA",
#     "url": "http://twitter.com/search?q=%22Trump%27s+FEMA%22",
#     "promoted_content": null,
#     "query": "%22Trump%27s+FEMA%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Aung San Suu Kyi",
#     "url": "http://twitter.com/search?q=%22Aung+San+Suu+Kyi%22",
#     "promoted_content": null,
#     "query": "%22Aung+San+Suu+Kyi%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stonehenge",
#     "url": "http://twitter.com/search?q=Stonehenge",
#     "promoted_content": null,
#     "query": "Stonehenge",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hyuna",
#     "url": "http://twitter.com/search?q=Hyuna",
#     "promoted_content": null,
#     "query": "Hyuna",
#     "tweet_volume": 791541
#    },
#    {
#     "name": "Debra Messing",
#     "url": "http://twitter.com/search?q=%22Debra+Messing%22",
#     "promoted_content": null,
#     "query": "%22Debra+Messing%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Oahu",
#     "url": "http://twitter.com/search?q=Oahu",
#     "promoted_content": null,
#     "query": "Oahu",
#     "tweet_volume": null
#    },
#    {
#     "name": "Superman",
#     "url": "http://twitter.com/search?q=Superman",
#     "promoted_content": null,
#     "query": "Superman",
#     "tweet_volume": 278927
#    },
#    {
#     "name": "Anuel",
#     "url": "http://twitter.com/search?q=Anuel",
#     "promoted_content": null,
#     "query": "Anuel",
#     "tweet_volume": 49447
#    },
#    {
#     "name": "Puerto Rico",
#     "url": "http://twitter.com/search?q=%22Puerto+Rico%22",
#     "promoted_content": null,
#     "query": "%22Puerto+Rico%22",
#     "tweet_volume": 292484
#    },
#    {
#     "name": "American Horror Story",
#     "url": "http://twitter.com/search?q=%22American+Horror+Story%22",
#     "promoted_content": null,
#     "query": "%22American+Horror+Story%22",
#     "tweet_volume": 43619
#    },
#    {
#     "name": "60 Minutes",
#     "url": "http://twitter.com/search?q=%2260+Minutes%22",
#     "promoted_content": null,
#     "query": "%2260+Minutes%22",
#     "tweet_volume": 22464
#    },
#    {
#     "name": "Norm Macdonald",
#     "url": "http://twitter.com/search?q=%22Norm+Macdonald%22",
#     "promoted_content": null,
#     "query": "%22Norm+Macdonald%22",
#     "tweet_volume": 23931
#    },
#    {
#     "name": "Abel Nazario",
#     "url": "http://twitter.com/search?q=%22Abel+Nazario%22",
#     "promoted_content": null,
#     "query": "%22Abel+Nazario%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "How to Murder Your Husband",
#     "url": "http://twitter.com/search?q=%22How+to+Murder+Your+Husband%22",
#     "promoted_content": null,
#     "query": "%22How+to+Murder+Your+Husband%22",
#     "tweet_volume": 26928
#    },
#    {
#     "name": "Designing Women",
#     "url": "http://twitter.com/search?q=%22Designing+Women%22",
#     "promoted_content": null,
#     "query": "%22Designing+Women%22",
#     "tweet_volume": 17483
#    },
#    {
#     "name": "#HappyBirthdayNiall",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayNiall",
#     "promoted_content": null,
#     "query": "%23HappyBirthdayNiall",
#     "tweet_volume": 91516
#    },
#    {
#     "name": "#DMEXCO18",
#     "url": "http://twitter.com/search?q=%23DMEXCO18",
#     "promoted_content": null,
#     "query": "%23DMEXCO18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#bfc530",
#     "url": "http://twitter.com/search?q=%23bfc530",
#     "promoted_content": null,
#     "query": "%23bfc530",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GaneshChaturthi",
#     "url": "http://twitter.com/search?q=%23GaneshChaturthi",
#     "promoted_content": null,
#     "query": "%23GaneshChaturthi",
#     "tweet_volume": 159665
#    },
#    {
#     "name": "#WaffleHouseIndex",
#     "url": "http://twitter.com/search?q=%23WaffleHouseIndex",
#     "promoted_content": null,
#     "query": "%23WaffleHouseIndex",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NYCVotes",
#     "url": "http://twitter.com/search?q=%23NYCVotes",
#     "promoted_content": null,
#     "query": "%23NYCVotes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AfricaTravelSummit",
#     "url": "http://twitter.com/search?q=%23AfricaTravelSummit",
#     "promoted_content": null,
#     "query": "%23AfricaTravelSummit",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AHSApocolypse",
#     "url": "http://twitter.com/search?q=%23AHSApocolypse",
#     "promoted_content": null,
#     "query": "%23AHSApocolypse",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MIGlobal",
#     "url": "http://twitter.com/search?q=%23MIGlobal",
#     "promoted_content": null,
#     "query": "%23MIGlobal",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AppleEvent",
#     "url": "http://twitter.com/search?q=%23AppleEvent",
#     "promoted_content": null,
#     "query": "%23AppleEvent",
#     "tweet_volume": 1031688
#    },
#    {
#     "name": "#NationalVideoGamesDay",
#     "url": "http://twitter.com/search?q=%23NationalVideoGamesDay",
#     "promoted_content": null,
#     "query": "%23NationalVideoGamesDay",
#     "tweet_volume": 115542
#    },
#    {
#     "name": "#WednesdayWisdom",
#     "url": "http://twitter.com/search?q=%23WednesdayWisdom",
#     "promoted_content": null,
#     "query": "%23WednesdayWisdom",
#     "tweet_volume": 131076
#    },
#    {
#     "name": "#NeverForget",
#     "url": "http://twitter.com/search?q=%23NeverForget",
#     "promoted_content": null,
#     "query": "%23NeverForget",
#     "tweet_volume": 88426
#    },
#    {
#     "name": "#GCAS2018",
#     "url": "http://twitter.com/search?q=%23GCAS2018",
#     "promoted_content": null,
#     "query": "%23GCAS2018",
#     "tweet_volume": 21801
#    },
#    {
#     "name": "#ONA18",
#     "url": "http://twitter.com/search?q=%23ONA18",
#     "promoted_content": null,
#     "query": "%23ONA18",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AMAs",
#     "url": "http://twitter.com/search?q=%23AMAs",
#     "promoted_content": null,
#     "query": "%23AMAs",
#     "tweet_volume": 723962
#    },
#    {
#     "name": "#BTSonAGT",
#     "url": "http://twitter.com/search?q=%23BTSonAGT",
#     "promoted_content": null,
#     "query": "%23BTSonAGT",
#     "tweet_volume": 1519031
#    },
#    {
#     "name": "#SavageXFenty",
#     "url": "http://twitter.com/search?q=%23SavageXFenty",
#     "promoted_content": null,
#     "query": "%23SavageXFenty",
#     "tweet_volume": 38657
#    },
#    {
#     "name": "#AskACurator",
#     "url": "http://twitter.com/search?q=%23AskACurator",
#     "promoted_content": null,
#     "query": "%23AskACurator",
#     "tweet_volume": 10663
#    },
#    {
#     "name": "#WorldOfDance",
#     "url": "http://twitter.com/search?q=%23WorldOfDance",
#     "promoted_content": null,
#     "query": "%23WorldOfDance",
#     "tweet_volume": 12599
#    },
#    {
#     "name": "#USAvMEX",
#     "url": "http://twitter.com/search?q=%23USAvMEX",
#     "promoted_content": null,
#     "query": "%23USAvMEX",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MAGARallyRules",
#     "url": "http://twitter.com/search?q=%23MAGARallyRules",
#     "promoted_content": null,
#     "query": "%23MAGARallyRules",
#     "tweet_volume": 16871
#    },
#    {
#     "name": "#WNBAFinals",
#     "url": "http://twitter.com/search?q=%23WNBAFinals",
#     "promoted_content": null,
#     "query": "%23WNBAFinals",
#     "tweet_volume": 12097
#    },
#    {
#     "name": "#HRTechConf",
#     "url": "http://twitter.com/search?q=%23HRTechConf",
#     "promoted_content": null,
#     "query": "%23HRTechConf",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DWTS",
#     "url": "http://twitter.com/search?q=%23DWTS",
#     "promoted_content": null,
#     "query": "%23DWTS",
#     "tweet_volume": 11171
#    }
#   ],
#   "as_of": "2018-09-13T11:24:22Z",
#   "created_at": "2018-09-13T11:19:25Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['pakistan'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
trends_set
# Out:
# {'world': {'#13settembre',
#   '#ArunJaitleyStepDown',
#   '#DER18Madrid',
#   '#DiaInternacionalDelChocolate',
#   '#FMQs',
#   '#FelizJueves',
#   '#GaneshChaturthi',
#   '#HambacherForst',
#   '#IPeekedOutMyWindow',
#   '#JeudiPhoto',
#   '#MetinOktay',
#   '#NSCKE2018',
#   '#PSGxJordan',
#   '#PersibDay',
#   '#Perşembe',
#   '#PlanPauvreté',
#   '#QuintaDetremuraSDV',
#   '#RoaldDahlDay2018',
#   '#SakaryaMeydanMuharebesi',
#   '#ThursdayThoughts',
#   '#WorldSepsisDay',
#   '#anipoke',
#   '#quizjam_ko',
#   '#اكله_مستحيل_تاكلها',
#   '#الخميس',
#   '#اليوم_العالمي_للقانون',
#   '#تصريح_مدير_جامعه_شقراء',
#   '#تكريم_اليسا',
#   '#جواز_الامارات_تاسع_اقوي_جواز',
#   '#رساله_توجهها_للحاسد',
#   '#عتق_رقبه_حمدان_النفيعي',
#   '#عطنا_حكمه_حلوه_من_عندك',
#   '#وجهك_طويل_او_قصير_او_دايري',
#   '#ぐるナイ',
#   '#公式ナカノヒトの悩み',
#   '#死ぬからの予測変換で生き返ってみせる',
#   '#레진대표_미성년자착취',
#   '#마음당_절대_안치이는_요소',
#   '#서랍안에_들어있는것',
#   'Franco del Valle',
#   'GT-R',
#   'Golden Sun',
#   'John Lewis',
#   'Merkez Bankası',
#   'Ruth Beitia',
#   'Salisbury Cathedral',
#   'VRカレシ',
#   'Солсбери',
#   'アニポケ',
#   '聚楽第'},
#  'us': {'#AHSApocolypse',
#   '#AMAs',
#   '#AfricaTravelSummit',
#   '#AppleEvent',
#   '#AskACurator',
#   '#BTSonAGT',
#   '#DMEXCO18',
#   '#DWTS',
#   '#FridayEve',
#   '#GCAS2018',
#   '#GaneshChaturthi',
#   '#HRTechConf',
#   '#HappyBirthdayNiall',
#   '#IPeekedOutMyWindow',
#   '#MAGARallyRules',
#   '#MIGlobal',
#   '#NYCVotes',
#   '#NationalVideoGamesDay',
#   '#NeverForget',
#   '#ONA18',
#   '#PrimaryDay',
#   '#SavageXFenty',
#   '#ThingsDuctTapeCantFix',
#   '#ThursdayThoughts',
#   '#USAvMEX',
#   '#WNBAFinals',
#   '#WaffleHouseIndex',
#   '#WednesdayWisdom',
#   '#WorldOfDance',
#   '#bfc530',
#   '60 Minutes',
#   'Abel Nazario',
#   'American Horror Story',
#   'Anuel',
#   'Aung San Suu Kyi',
#   'Bakersfield',
#   'Category 2',
#   'Debra Messing',
#   'Designing Women',
#   'How to Murder Your Husband',
#   'Hyuna',
#   'Norm Macdonald',
#   'Oahu',
#   'Puerto Rico',
#   'Stonehenge',
#   'Superman',
#   "Trump's FEMA",
#   'Vatican OKs'},
#  'pakistan': {'#ARYNewsUrdu',
#   '#AppleEvent',
#   '#BahriaTown',
#   '#BolNews',
#   '#California',
#   '#Fata',
#   '#HBDIramAhmadKhan',
#   '#HarSaansMeinBolo',
#   '#HussainSabKa',
#   '#Japan',
#   '#JusticeForSoniasFather',
#   '#KasautiiZindagiiKay',
#   '#KulsoomNawaz',
#   '#Muharram2018',
#   '#Myanmar',
#   '#NUST',
#   '#Pakistani',
#   '#Peshawar',
#   '#Putin',
#   '#Zionist',
#   '#america',
#   '#life',
#   '#مادرِجمہوریت',
#   'AbbTakk Headlines',
#   'Details Here',
#   'Double Fee',
#   'Islamic',
#   'London',
#   'May Allah',
#   'UPDATE II Niall',
#   'Watch Video'}}

# %%
for loc in ['world','us','pakistan']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #死ぬからの予測変換で生き返ってみせる,Солсбери,#GaneshChaturthi,#اليوم_العالمي_للقانون,#عتق_رقبه_حمدان_النفيعي,#DiaInternacionalDelChocolate,#anipoke,Franco del Valle,#PersibDay,#JeudiPhoto,アニポケ,#ぐるナイ,#NSCKE2018,#DER18Madrid,#레진대표_미성년자착취,VRカレシ,Merkez Bankası,#الخميس,#Perşembe,#QuintaDetremuraSDV,#جواز_الامارات_تاسع_اقوي_جواز,#公式ナカノヒトの悩み,#تكريم_اليسا,#FMQs,#PSGxJordan,#FelizJueves,#تصريح_مدير_جامعه_شقراء,#وجهك_طويل_او_قصير_او_دايري,#SakaryaMeydanMuharebesi,#ThursdayThoughts,#HambacherForst,GT-R,#PlanPauvreté,#마음당_절대_안치이는_요소,Salisbury Cathedral,Golden Sun,#MetinOktay,#13settembre,#quizjam_ko,#RoaldDahlDay2018,#رساله_توجهها_للحاسد,#서랍안에_들어있는것,#ArunJaitleyStepDown,#اكله_مستحيل_تاكلها,John Lewis,#WorldSepsisDay,#عطنا_حكمه_حلوه_من_عندك,#IPeekedOutMyWindow,Ruth Beitia,聚楽第
# ('----------', 'us')
# #PrimaryDay,#GaneshChaturthi,#MAGARallyRules,#AppleEvent,#FridayEve,#AskACurator,Trump's FEMA,American Horror Story,#HRTechConf,#GCAS2018,60 Minutes,Norm Macdonald,#HappyBirthdayNiall,#AHSApocolypse,Puerto Rico,#WNBAFinals,#NYCVotes,#ONA18,#SavageXFenty,#WorldOfDance,#BTSonAGT,Anuel,#MIGlobal,#WednesdayWisdom,#NeverForget,#ThingsDuctTapeCantFix,#ThursdayThoughts,#AMAs,Bakersfield,Debra Messing,#USAvMEX,#AfricaTravelSummit,#DWTS,Superman,How to Murder Your Husband,#bfc530,#DMEXCO18,Stonehenge,Oahu,#NationalVideoGamesDay,Vatican OKs,Aung San Suu Kyi,Abel Nazario,#IPeekedOutMyWindow,Category 2,Hyuna,Designing Women,#WaffleHouseIndex
# ('----------', 'pakistan')
# #HBDIramAhmadKhan,#AppleEvent,#KasautiiZindagiiKay,#Pakistani,May Allah,Double Fee,London,#Myanmar,#مادرِجمہوریت,#Muharram2018,#Peshawar,#California,#Zionist,#HarSaansMeinBolo,#BahriaTown,#ARYNewsUrdu,#Fata,#Putin,#BolNews,UPDATE II Niall,#NUST,#KulsoomNawaz,#america,AbbTakk Headlines,#Japan,#HussainSabKa,Details Here,Watch Video,#life,Islamic,#JusticeForSoniasFather

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and pakistan'))
print((trends_set['pakistan'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#ThursdayThoughts', '#GaneshChaturthi', '#IPeekedOutMyWindow'}
# ('==========', 'intersection of us and pakistan')
# {'#AppleEvent'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed

# %%
q = '#ThursdayThoughts' 

number = 100

#See https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html

search_results = twitter_api.search.tweets(q=q, count=number)

t_statuses = search_results['statuses']

# %%
print(len(t_statuses))
print(t_statuses)
# Out:
# 100
# [{'created_at': 'Thu Sep 13 11:47:20 +0000 2018', 'id': 1040205284231340033, 'id_str': '1040205284231340033', 'text': 'RT @TomHall: Patience of a Saint.\n\nOr should I say - a Mother! \n\n🐆\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa', 'truncated': False, 'entities': {'hashtags': [{'text': 'ThursdayThoughts', 'indices': [68, 85]}, {'text': 'Mom', 'indices': [86, 90]}, {'text': 'Motherhood', 'indices': [91, 102]}], 'symbols': [], 'user_mentions': [{'screen_name': 'TomHall', 'name': 'Tom Hall ☘', 'id': 14993272, 'id_str': '14993272', 'indices': [3, 11]}], 'urls': [], 'media': [{'id': 918838873160953856, 'id_str': '918838873160953856', 'indices': [105, 128], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg', 'url': 'https://t.co/7bNvRGYyUa', 'display_url': 'pic.twitter.com/7bNvRGYyUa', 'expanded_url': 'https://twitter.com/KykNoord_/status/918839062563311616/video/1', 'type': 'photo', 'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 480, 'h': 480, 'resize': 'fit'}, 'medium': {'w': 480, 'h': 480, 'resize': 'fit'}}, 'source_status_id': 918839062563311616, 'source_status_id_str': '918839062563311616', 'source_user_id': 749619139, 'source_user_id_str': '749619139'}]}, 'extended_entities': {'media': [{'id': 918838873160953856, 'id_str': '918838873160953856', 'indices': [105, 128], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg', 'url': 'https://t.co/7bNvRGYyUa', 'display_url': 'pic.twitter.com/7bNvRGYyUa', 'expanded_url': 'https://twitter.com/KykNoord_/status/918839062563311616/video/1', 'type': 'video', 'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 480, 'h': 480, 'resize': 'fit'}, 'medium': {'w': 480, 'h': 480, 'resize': 'fit'}}, 'source_status_id': 918839062563311616, 'source_status_id_str': '918839062563311616', 'source_user_id': 749619139, 'source_user_id_str': '749619139', 'video_info': {'aspect_ratio': [1, 1], 'duration_millis': 43608, 'variants': [{'bitrate': 256000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/240x240/Qa5tMu1lM-16PDIF.mp4'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/480x480/sQcCbVAsOE_msWVg.mp4'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/pl/8RzEuj3KnjhIwO7_.m3u8'}]}, 'additional_media_info': {'monetizable': False}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2802269902, 'id_str': '2802269902', 'name': 'Daisy', 'screen_name': 'DaisyCatNine', 'location': 'Washington, DC', 'description': "I'm a literary cat and I tweet about books when I'm not napping.", 'url': 'http://t.co/Y4qKd2UNC0', 'entities': {'url': {'urls': [{'url': 'http://t.co/Y4qKd2UNC0', 'expanded_url': 'http://ninespeakers.com', 'display_url': 'ninespeakers.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 16255, 'friends_count': 15862, 'listed_count': 611, 'created_at': 'Fri Oct 03 16:48:14 +0000 2014', 'favourites_count': 46869, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 161547, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': Fa ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
statuses = []
for s in t_statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 83

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @TomHall: Patience of a Saint.\n\nOr should I say - a Mother! \n\n🐆\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa',
#  'RT @pinkk9lover: Lying just doesn’t stop for people like @HillaryClinton . Her latest twitter rant purposely mischaracterizes #JudgeKavenau…',
#  'Happy #ThursdayThoughts ! :)💖👑 #ThursdayMotivation #BringItOn #YouveGotThis #September #wishes https://t.co/NgRJ2YS0TM',
#  'RT @pinkk9lover: There are at least 65 million of us that love the USA and @POTUS ! Now let that show at the polls in  #NovemberMidTerms \nN…',
#  'LATEST: @HighclereCastle Cigar Tasting Session Review. Fantastic night down at @Turmeaus Chester with @Tor_Imports… https://t.co/aArs8WmZcI',
#  '#PrimaryDay time to elect the #Corrupt and #Crooked liberal Space Cadet Cuomo Since Nixon has zero chance of winnin… https://t.co/3woiMBZjlD',
#  'Couple of us did a whole review of Jiggas library. Thoughts?\n#ThursdayThoughts #JayZ @S_C_ https://t.co/a1ohEq9IkF',
#  '#ThursdayThoughts https://t.co/229BbLqNJJ',
#  'RT @RealDonaldTrFan: Just found out NOAA (National Oceanic &amp; Atmospheric something) is flying airplanes INTO the Cat 2 Hurricaine! WHY THE…',
#  'RT @johnpavlovitz: "Life is stunningly short and it is eggshell fragile.\nPeople almost always in more pain than you think they are.\nDon\'t b…',
#  'RT @SwamiGeetika: "Where there is devotion, God always manifests himself with his gracious presence."\nMay This Ganesh Chaturthi Lord Ganesh…',
#  'RT @Miccoliofficial: #RoaldDahlDay2018 #ThursdayThoughts #thursdaymotivation #RoaldDahlworldcup2018 Group B! 🏆📚4 groups in total 🏆📚@roald_d…',
#  'I feel like red is the most pretentious color of sports car #ThursdayThoughts',
#  'RT @EtsyJeweler: These are cute. https://t.co/kTxoLhuUWu #etsy #etsychaching #ThursdayThoughts #Earring https://t.co/dDCXHs6cPU',
#  '#ThursdayThoughts\nFloods',
#  'RT @Manju41847909: #ThursdayThoughts\nपूरब पश्चिम उत्तर दक्षिण फिरता दाने-दाने नूं।\nसर्व कला सतगुरु साहिब की #Hari_Aaye_Haryane_Nu\nअवश्य जा…',
#  'RT @MadLipz_SA: Dear @SimbaChipsSA \nThank you for an awesome childhood 🙏\n#TBT\n#Madlipz\n#DBZTazzo \n#Madlipz_SA  \n#TBTMadLipz\n#ThursdayThough…',
#  'RT @Kristinscrosses: Thursday:\nPray the Luminous Mysteries\nof the Holy Rosary\n✨\n1️⃣ Baptism of Jesus\n2️⃣ Miracle at the Wedding at Cana\n3️⃣…',
#  "RT @MarkoSilberhand: Thanks @Twitter ! First 12 hours in your jail, (something about 'white trash' and a Fake-Fox host) and now #Shadowbann…",
#  'RT @TomHall: Patience of a Saint.\n\nOr should I say - a Mother! \n\n🐆\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa',
#  'RT @Casa_Rodrigues_: Views of the WTC from the Battery Oval, NYC 9-3-18\n\n#nyc #SeeYourCity #StormHour @NYCDailyPics @nycfeelings @following…',
#  'RT @DiasporaCongo: It is not about getting OBEDIENCE. It is about earning LOYALTY.  It is not about commanding ATTENTION.  It is about buil…',
#  "RT @immelza: Today we're counting on our #BlueWave Friends in #NewYork to go vote your asses off it's #ElectionDay Take friends and family…",
#  'Currently obsessed w/ this quote! 💕\n\n#ThursdayThoughts #quoteoftheday #quotestoliveby  #Wisdom https://t.co/MrxVZ71nlg',
#  '“I’ll drink to that.”\n          - me to everything \n#ThursdayThoughts',
#  'This Brexit is shit. Glad roaming charges are coming back. Glad everything is going up in price and the ppl who wan… https://t.co/oBdrkTE02d',
#  'RT @EnjoyNature: Red Tulips and Spring Golden Sunset\n\n#Travel #Nature #Photo #Flowers #Plants #Flower #Gardening #Weather #Tulips\n#Sunset #…',
#  'RT @TheRealNemxsis: @altontowers #thursdaythoughts which queue is the most exciting rn?',
#  'RT @tarheel_texas: Seriously @DuckDuckGo is free &amp; seems #Patriot spirit to me for search, no ads and no tracking so #WhathaveWeGotToLose #…',
#  'RT @SwamiGeetika: "Where there is devotion, God always manifests himself with his gracious presence."\nMay This Ganesh Chaturthi Lord Ganesh…',
#  'RT @ValaAfshar: Family first\nShow appreciation\nBe honest\nStay healthy and fit\nKeep in touch with friends\nYou are not your job\nForgive first…',
#  'RT @RealDonaldTrFan: Just found out NOAA (National Oceanic &amp; Atmospheric something) is flying airplanes INTO the Cat 2 Hurricaine! WHY THE…',
#  'My Philanthropy Work Never Stops Inspiring and Motivating Me to Be More So I Can Do More https://t.co/OMemPDjbOM… https://t.co/JwrPCSJyUQ',
#  'RT @tim_fargo: Happiness is a butterfly, which when pursued, is always beyond your grasp, but which, if you will sit down... ―Nathaniel Haw…',
#  'RT @LenisseCrochet: Newborn pixie hats Newborn Pixie bonnet / photography props / newborn baby girl … by LenisseCrochet via @Etsy Place you…',
#  'Be you.\n\nThe world will adjust.\n\n#believeinyourself \n#quote \n#ThursdayThoughts',
#  "RT @PhantomOpera: Close your eyes, let your spirit start to soar!\nAnd you'll live as you've never lived before...\n\n#ThursdayThoughts https:…",
#  'THE best place for lunch! 😍😍\n#Bristol #ThursdayThoughts https://t.co/D93HxCMqPJ',
#  'Refashioned design and new technology: the new SKODA FABIA in action #ThursdayThoughts https://t.co/31GezWfl0Y',
#  "RT @natlibscot: Happy #RoaldDahlDay2018 everyone! Listen to Matilda - she's a canny one.\n\n#ThursdayThoughts https://t.co/wcnao1mgWC",
#  '#ThursdayThoughts https://t.co/YhPWNK5Nv4',
#  'RT @EconoFactOrg: US policies can only be as strong as the facts which support them. Sign up for our newsletter to get dispassionate analys…',
#  'RT @TheEugeOptimist: I’ll say this again, if only 37% of Americans think BK should be confirmed, who are these senators actually representi…',
#  'RT @mikandynothem: Excellent, @JohnKStahlUSA...\n\n#MAGA #tcot #ThursdayThoughts\n#MAGARallyRules #Cities4Climate\n#WalkAway https://t.co/RqiAB…',
#  'RT @ColegGwentBiz: Have you considered an apprenticeship as your next step? #Apprenticeships #ThursdayThoughts Find out more: https://t.co/…',
#  'RT @bill_auclair: POTUS* response to Admiral Rogers\' repeated warnings of #Russian cyberattacks: "Mike, you know I\'m in a different place."…',
#  'RT @johnpavlovitz: "Life is stunningly short and it is eggshell fragile.\nPeople almost always in more pain than you think they are.\nDon\'t b…',
#  '#RoaldDahlDay2018 #ThursdayThoughts #thursdaymotivation #RoaldDahlworldcup2018 Group B! 🏆📚4 groups in total 🏆📚@roald_dahl @Booktrust',
#  'RT @RealDonaldTrFan: Just found out NOAA (National Oceanic &amp; Atmospheric something) is flying airplanes INTO the Cat 2 Hurricaine! WHY THE…',
#  'RT @DrRupesh1234: #ThursdayThoughts\nजैसी संगत में इंसान रहता है वैसे ही होता चला जाता है । आज के बुरे समय को देखते हुए संत रामपाल जी महाराज…',
#  'Global #Stocks are positive ahead of ECB rate decision after US proposes continued #trade discussions with China...… https://t.co/mdYJnyQlUD',
#  'RT @AMErikaNGIRLBOT: Sad. Socialism Failed Venezuela. The Rich were able to escape the reality of it’s political failures, while the poor s…',
#  'RT @worldkidneyday: #KidneyDisease is a #SilentKiller. You can lose up to 90% of your #KidneyFunction before you develop #Symptoms of #Chro…',
#  '#LadyGaga Gets Real About #MentalHealth Struggles, Inspires Us with Her Raw Honesty. https://t.co/48SC5fjMfK… https://t.co/JtCHen3RxI',
#  "become part of the self-love club....\n\nWTF I'm Trying to Be #Spiritual (Guidebook &amp; Workbook)\nSpirit-based books on… https://t.co/SiyG9dbmQ2",
#  "RT @The_Animal_Team: Troy deserves a really special home where he will get lots of TLC &amp; attention. He'd be suited to a quieter home where…",
#  'RT @kbari12: Lawful Term in USA @Twitter @TheJusticeDept @USSupremeCourt @WhiteHouse @realDonaldTrump First Amendment Under Attack by Tech…',
#  "RT @WireHouseES: The HSE's Go Home Healthy campaign encourages employers to protect their employee’s health and maintain a happy quality of…",
#  'RT @hindujagrutiorg: #ThursdayThoughts \nजानिए गणेश चतुर्थी का पूजन विधि ! #GaneshChaturthi Lord Ganesha\n तथा गणेशोत्सव काल में नित्य की तुल…',
#  'How did yall hide 20,000 bottles of water in Puerto Rico and then expect people to drink it after a year of sitting… https://t.co/9T1Xml4uNY',
#  'RT @AbiCat_tales: Treat others how you wish to be treated #fluffyfursday #ThursdayMotivation #ThursdayThoughts https://t.co/4SnF5xWOGR',
#  'RT @tim_fargo: Happiness is a butterfly, which when pursued, is always beyond your grasp, but which, if you will sit down... ―Nathaniel Haw…',
#  '@realDonaldTrump Let’s hope you do better than your “stellar” performance in Puerto Rico! No matter what you’ll giv… https://t.co/hx0bWgLZlr',
#  'RT @johnpavlovitz: "Life is stunningly short and it is eggshell fragile.\nPeople almost always in more pain than you think they are.\nDon\'t b…',
#  "Ugh. Mum collapsed and hit her head. Had to take her to hospital. Scary moment. Doc says she's okay, but scary mome… https://t.co/kAv0fFzyVR",
#  "@realDonaldTrump he's not the investigator and doesn't have the info that #Mueller has. it's ofver for you, you're… https://t.co/gUCCl7oMth",
#  'RT @pinkk9lover: Lying just doesn’t stop for people like @HillaryClinton . Her latest twitter rant purposely mischaracterizes #JudgeKavenau…',
#  'RT @EricMMatheny: We put way too much stake in celebrities and what they have to say.\n\nThey may have wealth and fame, but never forget...th…',
#  'RT @SwamiGeetika: "Where there is devotion, God always manifests himself with his gracious presence."\nMay This Ganesh Chaturthi Lord Ganesh…',
#  'RT @LucasBryner3: SEPTEMBER IS YOUR MONTH ✨\n\nSEPTEMBER IS YOUR MONTH ✨\n\nSEPTEMBER IS YOUR MONTH ✨\n\nSEPTEMBER IS YOUR MONTH ✨\n\nSEPTEMBER IS…',
#  '#IPeekedOutMyWindow to see a beautiful welcoming a new day🌄 #ThursdayThoughts #PrimaryDay https://t.co/6s1I3h0Fts',
#  'RT @pinkk9lover: Lying just doesn’t stop for people like @HillaryClinton . Her latest twitter rant purposely mischaracterizes #JudgeKavenau…',
#  'RT @pinkk9lover: There are at least 65 million of us that love the USA and @POTUS ! Now let that show at the polls in  #NovemberMidTerms \nN…',
#  '#ThursdayThoughts This predicted in by Orwell.  They will simply take away words you are allowed to say.  Welcome t… https://t.co/eqUKcucgaI',
#  'Is anyone an intellectual who values fan engagement. Acknowledges its audience. Understands what their audience wan… https://t.co/dEEjae4L6i',
#  'Some food for thought today...\n\nOur building is a community full of life, nurturing a diverse range of people and e… https://t.co/idmVk6xkhR',
#  'RT @daviddomoney: 🤒 with plants in their 🏥 room during post-surgery recovery have better health outcomes than those who don’t. They experie…',
#  'RT @OKAsia_djPanic: #ThursdayThoughts\n#OKAsia will be celebrating @BTS_twt #BTS(Mr. Dimples) #RMDay Saturday. Please tune in on WXOJ 103.3F…',
#  'RT @Santosh101989: #ThursdayThoughts\nगुरु के बिना मोक्ष संभव नहीं \nअर्थ श्री गुरु नानक जी ने कहा है कि गुरु के बिना भक्ति सफल नहीं हो सकती…',
#  "RT @natlibscot: Happy #RoaldDahlDay2018 everyone! Listen to Matilda - she's a canny one.\n\n#ThursdayThoughts https://t.co/wcnao1mgWC",
#  'RT @UYAFPAH1: "Gender equality is more than a goal in itself. It is a precondition for meeting the challenge of reducing poverty, promoting…',
#  "RT @PepperResists: #ThursdayThoughts\n\nIt's #PrimaryDay for #NewYork\n\nLook 👇and know what to do.\n\nEvery single vote is important and we all…",
#  'RT @pinkk9lover: There are at least 65 million of us that love the USA and @POTUS ! Now let that show at the polls in  #NovemberMidTerms \nN…',
#  'Mike, your tail is showing. #ThursdayThoughts #PenceKnew https://t.co/sSQfyAR9iJ',
#  'RT @LadyLibertyInEx: You walked away alone...now join together in DC!! \nWE’RE MARCHING JUST BEFORE MIDTERMS!\n#Walkaway #WalkAwayMarch #Walk…',
#  'RT @joshaldilli: #खट्टरसरकार_इस्तीफादो जो बरवाला काण्ड के दोषी है उन्हें सजा नहीं निर्दोष भगतो पर किया गया अत्याचार जो IGअनिल राव की और हरि…',
#  'RT @John_KissMyBot: Sorry Obama, Trump Did Build This And You Can’t Take Credit For It !!\n\n9 Out Of 10 Employees Are Satisfied With Their J…',
#  'RT @davepperlmutter: 5* Turbulent ride that had me biting my nails to the very end. Definitely recommend. https://t.co/JEEIbaMKuD  #BOOKBOO…',
#  'RT @WhoKares34: Good morning, happy Thursday! This is your daily reminder that the @GOP @SpeakerRyan &amp; @SenMajLdr continue to put our count…',
#  'RT @pinkk9lover: There are at least 65 million of us that love the USA and @POTUS ! Now let that show at the polls in  #NovemberMidTerms \nN…',
#  'And now, a message from the anti-@MaxineWaters \n#scalise #politics #ThursdayThoughts #foxnews #Trump #MAGA https://t.co/cGQ4GuPQpi',
#  'How does your business protect against ransomware? MTech believe reliable backup is the place to start. #Backup… https://t.co/T1ttxVUcIf',
#  "RT @IWW_Couriers: #ThursdayThoughts. Courier organising in the #gigeconomy isn't restricted by countries. Our pals across Europe are a mass…",
#  "It's days like these when I really miss the Jag...😉\n#ThursdayThoughts \n#shaunevans #endeavour #morse… https://t.co/TnhGF2GG2i",
#  '@altontowers #thursdaythoughts which queue is the most exciting rn?',
#  'RT @hindujagrutiorg: #ThursdayThoughts \nजानिए गणेश चतुर्थी का पूजन विधि ! #GaneshChaturthi Lord Ganesha\n तथा गणेशोत्सव काल में नित्य की तुल…',
#  'RT @RealDonaldTrFan: Just found out NOAA (National Oceanic &amp; Atmospheric something) is flying airplanes INTO the Cat 2 Hurricaine! WHY THE…',
#  'RT @AMErikaNGIRLBOT: Sad. Socialism Failed Venezuela. The Rich were able to escape the reality of it’s political failures, while the poor s…',
#  'RT @MistralKDawn: Can Petri #protect her #friends from the #dangers lurking in her past?\n\nhttps://t.co/m7JVbkiZ43\n\n#cyberpunk\n#scifi\n#dysto…',
#  "RT @True_IslamUK: Zee TV's 'Out &amp; About' program to feature #Ahmadiyya Muslim Youth Association UK's #Mercy4Mankind Charity Cheque Presenta…"]

# %%
statuses[0]
# Out:
# {'created_at': 'Thu Sep 13 11:47:20 +0000 2018',
#  'id': 1040205284231340033,
#  'id_str': '1040205284231340033',
#  'text': 'RT @TomHall: Patience of a Saint.\n\nOr should I say - a Mother! \n\n🐆\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa',
#  'truncated': False,
#  'entities': {'hashtags': [{'text': 'ThursdayThoughts', 'indices': [68, 85]},
#    {'text': 'Mom', 'indices': [86, 90]},
#    {'text': 'Motherhood', 'indices': [91, 102]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'TomHall',
#     'name': 'Tom Hall ☘',
#     'id': 14993272,
#     'id_str': '14993272',
#     'indices': [3, 11]}],
#   'urls': [],
#   'media': [{'id': 918838873160953856,
#     'id_str': '918838873160953856',
#     'indices': [105, 128],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#     'url': 'https://t.co/7bNvRGYyUa',
#     'display_url': 'pic.twitter.com/7bNvRGYyUa',
#     'expanded_url': 'https://twitter.com/KykNoord_/status/918839062563311616/video/1',
#     'type': 'photo',
#     'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 480, 'h': 480, 'resize': 'fit'},
#      'medium': {'w': 480, 'h': 480, 'resize': 'fit'}},
#     'source_status_id': 918839062563311616,
#     'source_status_id_str': '918839062563311616',
#     'source_user_id': 749619139,
#     'source_user_id_str': '749619139'}]},
#  'extended_entities': {'media': [{'id': 918838873160953856,
#     'id_str': '918838873160953856',
#     'indices': [105, 128],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#     'url': 'https://t.co/7bNvRGYyUa',
#     'display_url': 'pic.twitter.com/7bNvRGYyUa',
#     'expanded_url': 'https://twitter.com/KykNoord_/status/918839062563311616/video/1',
#     'type': 'video',
#     'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 480, 'h': 480, 'resize': 'fit'},
#      'medium': {'w': 480, 'h': 480, 'resize': 'fit'}},
#     'source_status_id': 918839062563311616,
#     'source_status_id_str': '918839062563311616',
#     'source_user_id': 749619139,
#     'source_user_id_str': '749619139',
#     'video_info': {'aspect_ratio': [1, 1],
#      'duration_millis': 43608,
#      'variants': [{'bitrate': 256000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/240x240/Qa5tMu1lM-16PDIF.mp4'},
#       {'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/480x480/sQcCbVAsOE_msWVg.mp4'},
#       {'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/pl/8RzEuj3KnjhIwO7_.m3u8'}]},
#     'additional_media_info': {'monetizable': False}}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2802269902,
#   'id_str': '2802269902',
#   'name': 'Daisy',
#   'screen_name': 'DaisyCatNine',
#   'location': 'Washington, DC',
#   'description': "I'm a literary cat and I tweet about books when I'm not napping.",
#   'url': 'http://t.co/Y4qKd2UNC0',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/Y4qKd2UNC0',
#       'expanded_url': 'http://ninespeakers.com',
#       'display_url': 'ninespeakers.com',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 16255,
#   'friends_count': 15862,
#   'listed_count': 611,
#   'created_at': 'Fri Oct 03 16:48:14 +0000 2014',
#   'favourites_count': 46869,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 161547,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/518082529446752256/HAJ_dKV7_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/518082529446752256/HAJ_dKV7_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2802269902/1412355831',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Thu Sep 13 06:31:39 +0000 2018',
#   'id': 1040125838836940800,
#   'id_str': '1040125838836940800',
#   'text': 'Patience of a Saint.\n\nOr should I say - a Mother! \n\n🐆\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'ThursdayThoughts', 'indices': [55, 72]},
#     {'text': 'Mom', 'indices': [73, 77]},
#     {'text': 'Motherhood', 'indices': [78, 89]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 918838873160953856,
#      'id_str': '918838873160953856',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#      'url': 'https://t.co/7bNvRGYyUa',
#      'display_url': 'pic.twitter.com/7bNvRGYyUa',
#      'expanded_url': 'https://twitter.com/KykNoord_/status/918839062563311616/video/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 480, 'h': 480, 'resize': 'fit'},
#       'medium': {'w': 480, 'h': 480, 'resize': 'fit'}},
#      'source_status_id': 918839062563311616,
#      'source_status_id_str': '918839062563311616',
#      'source_user_id': 749619139,
#      'source_user_id_str': '749619139'}]},
#   'extended_entities': {'media': [{'id': 918838873160953856,
#      'id_str': '918838873160953856',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg',
#      'url': 'https://t.co/7bNvRGYyUa',
#      'display_url': 'pic.twitter.com/7bNvRGYyUa',
#      'expanded_url': 'https://twitter.com/KykNoord_/status/918839062563311616/video/1',
#      'type': 'video',
#      'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 480, 'h': 480, 'resize': 'fit'},
#       'medium': {'w': 480, 'h': 480, 'resize': 'fit'}},
#      'source_status_id': 918839062563311616,
#      'source_status_id_str': '918839062563311616',
#      'source_user_id': 749619139,
#      'source_user_id_str': '749619139',
#      'video_info': {'aspect_ratio': [1, 1],
#       'duration_millis': 43608,
#       'variants': [{'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/240x240/Qa5tMu1lM-16PDIF.mp4'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/480x480/sQcCbVAsOE_msWVg.mp4'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/918838873160953856/pu/pl/8RzEuj3KnjhIwO7_.m3u8'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 14993272,
#    'id_str': '14993272',
#    'name': 'Tom Hall ☘',
#    'screen_name': 'TomHall',
#    'location': 'Santa Monica, California',
#    'description': 'Premier Twitter Master to CEOs, Entertainers, #Influencers & Thought Leaders; We Build Strategic Twitter Followings. Connoisseur of Adventures & Cocktails! 🍸',
#    'url': 'https://t.co/7d2YivRyAH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/7d2YivRyAH',
#        'expanded_url': 'http://www.TomHall.info',
#        'display_url': 'TomHall.info',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 555123,
#    'friends_count': 544609,
#    'listed_count': 3327,
#    'created_at': 'Tue Jun 03 14:34:51 +0000 2008',
#    'favourites_count': 441664,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 38525,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0F0E0E',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/561672933160927232/RJUZ5Rxs_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/561672933160927232/RJUZ5Rxs_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14993272/1467313906',
#    'profile_link_color': 'F50A0A',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '0084B4',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 281,
#   'favorite_count': 803,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 281,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Thu Sep 13 11:47:20 +0000 2018",
#  "id": 1040205284231340033,
#  "id_str": "1040205284231340033",
#  "text": "RT @TomHall: Patience of a Saint.\n\nOr should I say - a Mother! \n\n\ud83d\udc06\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "ThursdayThoughts",
#     "indices": [
#      68,
#      85
#     ]
#    },
#    {
#     "text": "Mom",
#     "indices": [
#      86,
#      90
#     ]
#    },
#    {
#     "text": "Motherhood",
#     "indices": [
#      91,
#      102
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "TomHall",
#     "name": "Tom Hall \u2618",
#     "id": 14993272,
#     "id_str": "14993272",
#     "indices": [
#      3,
#      11
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 918838873160953856,
#     "id_str": "918838873160953856",
#     "indices": [
#      105,
#      128
#     ],
#     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#     "url": "https://t.co/7bNvRGYyUa",
#     "display_url": "pic.twitter.com/7bNvRGYyUa",
#     "expanded_url": "https://twitter.com/KykNoord_/status/918839062563311616/video/1",
#     "type": "photo",
#     "sizes": {
#      "small": {
#       "w": 480,
#       "h": 480,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "large": {
#       "w": 480,
#       "h": 480,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 480,
#       "h": 480,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 918839062563311616,
#     "source_status_id_str": "918839062563311616",
#     "source_user_id": 749619139,
#     "source_user_id_str": "749619139"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 918838873160953856,
#     "id_str": "918838873160953856",
#     "indices": [
#      105,
#      128
#     ],
#     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#     "url": "https://t.co/7bNvRGYyUa",
#     "display_url": "pic.twitter.com/7bNvRGYyUa",
#     "expanded_url": "https://twitter.com/KykNoord_/status/918839062563311616/video/1",
#     "type": "video",
#     "sizes": {
#      "small": {
#       "w": 480,
#       "h": 480,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "large": {
#       "w": 480,
#       "h": 480,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 480,
#       "h": 480,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 918839062563311616,
#     "source_status_id_str": "918839062563311616",
#     "source_user_id": 749619139,
#     "source_user_id_str": "749619139",
#     "video_info": {
#      "aspect_ratio": [
#       1,
#       1
#      ],
#      "duration_millis": 43608,
#      "variants": [
#       {
#        "bitrate": 256000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/240x240/Qa5tMu1lM-16PDIF.mp4"
#       },
#       {
#        "bitrate": 832000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/480x480/sQcCbVAsOE_msWVg.mp4"
#       },
#       {
#        "content_type": "application/x-mpegURL",
#        "url": "https://video.twimg.com/ext_tw_video/918838873160953856/pu/pl/8RzEuj3KnjhIwO7_.m3u8"
#       }
#      ]
#     },
#     "additional_media_info": {
#      "monetizable": false
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2802269902,
#   "id_str": "2802269902",
#   "name": "Daisy",
#   "screen_name": "DaisyCatNine",
#   "location": "Washington, DC",
#   "description": "I'm a literary cat and I tweet about books when I'm not napping.",
#   "url": "http://t.co/Y4qKd2UNC0",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/Y4qKd2UNC0",
#       "expanded_url": "http://ninespeakers.com",
#       "display_url": "ninespeakers.com",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 16255,
#   "friends_count": 15862,
#   "listed_count": 611,
#   "created_at": "Fri Oct 03 16:48:14 +0000 2014",
#   "favourites_count": 46869,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 161547,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/518082529446752256/HAJ_dKV7_normal.jpeg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/518082529446752256/HAJ_dKV7_normal.jpeg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2802269902/1412355831",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Thu Sep 13 06:31:39 +0000 2018",
#   "id": 1040125838836940800,
#   "id_str": "1040125838836940800",
#   "text": "Patience of a Saint.\n\nOr should I say - a Mother! \n\n\ud83d\udc06\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "ThursdayThoughts",
#      "indices": [
#       55,
#       72
#      ]
#     },
#     {
#      "text": "Mom",
#      "indices": [
#       73,
#       77
#      ]
#     },
#     {
#      "text": "Motherhood",
#      "indices": [
#       78,
#       89
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 918838873160953856,
#      "id_str": "918838873160953856",
#      "indices": [
#       92,
#       115
#      ],
#      "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#      "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#      "url": "https://t.co/7bNvRGYyUa",
#      "display_url": "pic.twitter.com/7bNvRGYyUa",
#      "expanded_url": "https://twitter.com/KykNoord_/status/918839062563311616/video/1",
#      "type": "photo",
#      "sizes": {
#       "small": {
#        "w": 480,
#        "h": 480,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "large": {
#        "w": 480,
#        "h": 480,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 480,
#        "h": 480,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 918839062563311616,
#      "source_status_id_str": "918839062563311616",
#      "source_user_id": 749619139,
#      "source_user_id_str": "749619139"
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 918838873160953856,
#      "id_str": "918838873160953856",
#      "indices": [
#       92,
#       115
#      ],
#      "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#      "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/918838873160953856/pu/img/mEX_9Z2iNsovi4NA.jpg",
#      "url": "https://t.co/7bNvRGYyUa",
#      "display_url": "pic.twitter.com/7bNvRGYyUa",
#      "expanded_url": "https://twitter.com/KykNoord_/status/918839062563311616/video/1",
#      "type": "video",
#      "sizes": {
#       "small": {
#        "w": 480,
#        "h": 480,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "large": {
#        "w": 480,
#        "h": 480,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 480,
#        "h": 480,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 918839062563311616,
#      "source_status_id_str": "918839062563311616",
#      "source_user_id": 749619139,
#      "source_user_id_str": "749619139",
#      "video_info": {
#       "aspect_ratio": [
#        1,
#        1
#       ],
#       "duration_millis": 43608,
#       "variants": [
#        {
#         "bitrate": 256000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/240x240/Qa5tMu1lM-16PDIF.mp4"
#        },
#        {
#         "bitrate": 832000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/ext_tw_video/918838873160953856/pu/vid/480x480/sQcCbVAsOE_msWVg.mp4"
#        },
#        {
#         "content_type": "application/x-mpegURL",
#         "url": "https://video.twimg.com/ext_tw_video/918838873160953856/pu/pl/8RzEuj3KnjhIwO7_.m3u8"
#        }
#       ]
#      },
#      "additional_media_info": {
#       "monetizable": false
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 14993272,
#    "id_str": "14993272",
#    "name": "Tom Hall \u2618",
#    "screen_name": "TomHall",
#    "location": "Santa Monica, California",
#    "description": "Premier Twitter Master to CEOs, Entertainers, #Influencers & Thought Leaders; We Build Strategic Twitter Followings. Connoisseur of Adventures & Cocktails! \ud83c\udf78",
#    "url": "https://t.co/7d2YivRyAH",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/7d2YivRyAH",
#        "expanded_url": "http://www.TomHall.info",
#        "display_url": "TomHall.info",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 555123,
#    "friends_count": 544609,
#    "listed_count": 3327,
#    "created_at": "Tue Jun 03 14:34:51 +0000 2008",
#    "favourites_count": 441664,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 38525,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "0F0E0E",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/561672933160927232/RJUZ5Rxs_normal.jpeg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/561672933160927232/RJUZ5Rxs_normal.jpeg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/14993272/1467313906",
#    "profile_link_color": "F50A0A",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "C0DFEC",
#    "profile_text_color": "0084B4",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 281,
#   "favorite_count": 803,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 281,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 1039794680861405184 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 281
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @TomHall: Patience of a Saint.\n\nOr should I say - a Mother! \n\n\ud83d\udc06\n\n#ThursdayThoughts #Mom #Motherhood \n\nhttps://t.co/7bNvRGYyUa",
#  "RT @pinkk9lover: Lying just doesn\u2019t stop for people like @HillaryClinton . Her latest twitter rant purposely mischaracterizes #JudgeKavenau\u2026",
#  "Happy #ThursdayThoughts ! :)\ud83d\udc96\ud83d\udc51 #ThursdayMotivation #BringItOn #YouveGotThis #September #wishes https://t.co/NgRJ2YS0TM",
#  "RT @pinkk9lover: There are at least 65 million of us that love the USA and @POTUS ! Now let that show at the polls in  #NovemberMidTerms \nN\u2026",
#  "LATEST: @HighclereCastle Cigar Tasting Session Review. Fantastic night down at @Turmeaus Chester with @Tor_Imports\u2026 https://t.co/aArs8WmZcI"
# ]
# [
#  "TomHall",
#  "pinkk9lover",
#  "HillaryClinton",
#  "pinkk9lover",
#  "POTUS"
# ]
# [
#  "ThursdayThoughts",
#  "Mom",
#  "Motherhood",
#  "ThursdayThoughts",
#  "ThursdayMotivation"
# ]
# [
#  "RT",
#  "@TomHall:",
#  "Patience",
#  "of",
#  "a"
# ]

# %% [markdown]
# ## Example 7. Converting to DataFrame

# %%
import pandas as pd

# %%
tweet_df = pd.DataFrame(t_statuses,index=None)

# %%
tweet_df.keys()
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'entities',
#        'extended_entities', 'favorite_count', 'favorited', 'geo', 'id',
#        'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'metadata',
#        'place', 'possibly_sensitive', 'quoted_status', 'quoted_status_id',
#        'quoted_status_id_str', 'retweet_count', 'retweeted',
#        'retweeted_status', 'source', 'text', 'truncated', 'user'],
#       dtype='object')

# %%
len(tweet_df)
# Out:
# 100

# %%
tweet_df = tweet_df.text.drop_duplicates()

# %%
len(tweet_df)
# Out:
# 83

# %% [markdown]
# ### Additional Links:
#
# 1. https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
